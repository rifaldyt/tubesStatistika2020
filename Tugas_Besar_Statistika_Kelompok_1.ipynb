# %% [markdown]
# Kelompok 1

# %% [markdown]
# Memanggil File CSV dari Google Drive

# %%
# Mengambil file csv dari google drive
# https://drive.google.com/open?id=1RkFMJAY0vNJkThT2DyNPx6OngNA7VLCX
system("gdown --id 1RkFMJAY0vNJkThT2DyNPx6OngNA7VLCX")

# %% [markdown]
# Membaca File CSV

# %%
BankChurners = read.csv("BankChurners.csv")
summary(BankChurners)
?BankChurners
# Out:
#    CLIENTNUM         Attrition_Flag      Customer_Age      Gender
#  Min.   :708082083   Length:10127       Min.   :26.00   Length:10127
#  1st Qu.:713036770   Class :character   1st Qu.:41.00   Class :character
#  Median :717926358   Mode  :character   Median :46.00   Mode  :character
#  Mean   :739177606                      Mean   :46.33
#  3rd Qu.:773143533                      3rd Qu.:52.00
#  Max.   :828343083                      Max.   :73.00
#  Dependent_count Education_Level    Marital_Status     Income_Category
#  Min.   :0.000   Length:10127       Length:10127       Length:10127
#  1st Qu.:1.000   Class :character   Class :character   Class :character
#  Median :2.000   Mode  :character   Mode  :character   Mode  :character
#  Mean   :2.346
#  3rd Qu.:3.000
#  Max.   :5.000
#  Card_Category      Months_on_book  Total_Relationship_Count
#  Length:10127       Min.   :13.00   Min.   :1.000
#  Class :character   1st Qu.:31.00   1st Qu.:3.000
# ...

# %% [markdown]
# Histogram Gender

# %%
a=table(BankChurners$Gender)
barplot(a,main="Using BarPlot to display Gender Comparision",
       ylab="Count",
       xlab="Gender",
       col=rainbow(2),
       legend=rownames(a))
# Out:
# Plot with title “Using BarPlot to display Gender Comparision”

# %%
#Boxplot Customer_Age dengan Gender
library(ggplot2)
# Rotate the box plot
#Jadi error
# Notched box plot
ggplot(BankChurners, aes(x=Customer_Age, y=Gender)) +
  geom_boxplot()
# Out:
# plot without title

# %%
# Histogram dari Customer Age dan Gender
ggplot(BankChurners, aes(x=Customer_Age, color=Gender)) +
  geom_histogram(fill="white")
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
# Histogram dari kolom Income Category
ggplot(data.frame(BankChurners), aes(x=Income_Category)) +
  geom_bar()
# Out:
# plot without title

# %% [markdown]
# Satu Variabel Diubah Menjadi 3 Diagram

# %%
# Kolom CLIENTNUM
# 1. Histogram
hist(BankChurners$CLIENTNUM)
# 2. Boxplot
ggplot(data.frame(BankChurners), aes(x=CLIENTNUM)) +
  geom_boxplot()
# 3. FreqPolygon
ggplot(data.frame(BankChurners), aes(x=CLIENTNUM)) +
  geom_freqpoly()
# Out:
# Plot with title “Histogram of BankChurners$CLIENTNUM”
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
# plot without title

# %%
# Kolom Customer Age
# 1. Histogram
hist(BankChurners$Customer_Age)
# 2. Boxplot
ggplot(data.frame(BankChurners), aes(x=Customer_Age)) +
  geom_boxplot()
# 3. FreqPolygon
ggplot(data.frame(BankChurners), aes(x=Customer_Age)) +
  geom_freqpoly()
# Out:
# Plot with title “Histogram of BankChurners$Customer_Age”
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
# plot without title

# %%
# Kolom Dependent Count
# 1. Histogram
hist(BankChurners$Dependent_count)
# 2. Boxplot
ggplot(data.frame(BankChurners), aes(x=Dependent_count)) +
  geom_boxplot()
# 3. FreqPolygon
ggplot(data.frame(BankChurners), aes(x=Dependent_count)) +
  geom_freqpoly()
# Out:
# Plot with title “Histogram of BankChurners$Dependent_count”
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
# plot without title

# %%
# Kolom Months_on_book
# 1. Histogram
hist(BankChurners$Months_on_book)
# 2. Boxplot
ggplot(data.frame(BankChurners), aes(x=Months_on_book)) +
  geom_boxplot()
# 3. FreqPolygon
ggplot(data.frame(BankChurners), aes(x=Months_on_book)) +
  geom_freqpoly()
# Out:
# Plot with title “Histogram of BankChurners$Months_on_book”
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
# plot without title

# %%
# Kolom Total_Relationship_Count
# 1. Histogram
hist(BankChurners$Total_Relationship_Count)
# 2. Boxplot
ggplot(data.frame(BankChurners), aes(x=Total_Relationship_Count)) +
  geom_boxplot()
# 3. FreqPolygon
ggplot(data.frame(BankChurners), aes(x=Total_Relationship_Count)) +
  geom_freqpoly()
# Out:
# Plot with title “Histogram of BankChurners$Total_Relationship_Count”
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
# plot without title

# %%
# Kolom Months_Inactive_12_mon
# 1. Histogram
hist(BankChurners$Months_Inactive_12_mon)
# 2. Boxplot
ggplot(data.frame(BankChurners), aes(x=Months_Inactive_12_mon)) +
  geom_boxplot()
# 3. FreqPolygon
ggplot(data.frame(BankChurners), aes(x=Months_Inactive_12_mon)) +
  geom_freqpoly()
# Out:
# Plot with title “Histogram of BankChurners$Months_Inactive_12_mon”
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
# plot without title

# %%
# Kolom Contacts_Count_12_mon
# 1. Histogram
hist(BankChurners$Contacts_Count_12_mon)
# 2. Boxplot
ggplot(data.frame(BankChurners), aes(x=Contacts_Count_12_mon)) +
  geom_boxplot()
# 3. FreqPolygon
ggplot(data.frame(BankChurners), aes(x=Contacts_Count_12_mon)) +
  geom_freqpoly()
# Out:
# Plot with title “Histogram of BankChurners$Contacts_Count_12_mon”
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
# plot without title

# %%
# Kolom Credit_Limit
# 1. Histogram
hist(BankChurners$Credit_Limit)
# 2. Boxplot
ggplot(data.frame(BankChurners), aes(x=Credit_Limit)) +
  geom_boxplot()
# 3. FreqPolygon
ggplot(data.frame(BankChurners), aes(x=Credit_Limit)) +
  geom_freqpoly()
# Out:
# Plot with title “Histogram of BankChurners$Credit_Limit”
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
# plot without title

# %%
# Kolom Total_Revolving_Bal
# 1. Histogram
hist(BankChurners$Total_Revolving_Bal)
# 2. Boxplot
ggplot(data.frame(BankChurners), aes(x=Total_Revolving_Bal)) +
  geom_boxplot()
# 3. FreqPolygon
ggplot(data.frame(BankChurners), aes(x=Total_Revolving_Bal)) +
  geom_freqpoly()
# Out:
# Plot with title “Histogram of BankChurners$Total_Revolving_Bal”
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
# plot without title

# %%
# Kolom Avg_Open_To_Buy
# 1. Histogram
hist(BankChurners$Avg_Open_To_Buy)
# 2. Boxplot
ggplot(data.frame(BankChurners), aes(x=Avg_Open_To_Buy)) +
  geom_boxplot()
# 3. FreqPolygon
ggplot(data.frame(BankChurners), aes(x=Avg_Open_To_Buy)) +
  geom_freqpoly()
# Out:
# Plot with title “Histogram of BankChurners$Avg_Open_To_Buy”
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
# plot without title

# %%
# Kolom Total_Amt_Chng_Q4_Q1
# 1. Histogram
hist(BankChurners$Total_Amt_Chng_Q4_Q1)
# 2. Boxplot
ggplot(data.frame(BankChurners), aes(x=Total_Amt_Chng_Q4_Q1)) +
  geom_boxplot()
# 3. FreqPolygon
ggplot(data.frame(BankChurners), aes(x=Total_Amt_Chng_Q4_Q1)) +
  geom_freqpoly()
# Out:
# Plot with title “Histogram of BankChurners$Total_Amt_Chng_Q4_Q1”
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
# plot without title

# %%
# Kolom Total_Trans_Amt
# 1. Histogram
hist(BankChurners$Total_Trans_Amt)
# 2. Boxplot
ggplot(data.frame(BankChurners), aes(x=Total_Trans_Amt)) +
  geom_boxplot()
# 3. FreqPolygon
ggplot(data.frame(BankChurners), aes(x=Total_Trans_Amt)) +
  geom_freqpoly()
# Out:
# Plot with title “Histogram of BankChurners$Total_Trans_Amt”
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
# plot without title

# %%
# Kolom Total_TraTotal_Trans_Ctns_Amt
# 1. Histogram
hist(BankChurners$Total_Trans_Ct)
# 2. Boxplot
ggplot(data.frame(BankChurners), aes(x=Total_Trans_Ct)) +
  geom_boxplot()
# 3. FreqPolygon
ggplot(data.frame(BankChurners), aes(x=Total_Trans_Ct)) +
  geom_freqpoly()
# Out:
# Plot with title “Histogram of BankChurners$Total_Trans_Ct”
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
# plot without title

# %%
# Kolom Total_Ct_Chng_Q4_Q1
# 1. Histogram
hist(BankChurners$Total_Ct_Chng_Q4_Q1)
# 2. Boxplot
ggplot(data.frame(BankChurners), aes(x=Total_Ct_Chng_Q4_Q1)) +
  geom_boxplot()
# 3. FreqPolygon
ggplot(data.frame(BankChurners), aes(x=Total_Ct_Chng_Q4_Q1)) +
  geom_freqpoly()
# Out:
# Plot with title “Histogram of BankChurners$Total_Ct_Chng_Q4_Q1”
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title
# plot without title

# %% [markdown]
# ScatterPlot

# %%
#Scatter Plot Customer Age (C) dengan Naive Bayes (V)
library(ggplot2)
ggplot(BankChurners, aes(x = Customer_Age, y = Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1)) +
    geom_point()
# Out:
# plot without title

# %%
#Scatter Plot Gender (D) dengan Naive Bayes (V)
ggplot(BankChurners, aes(x = Gender, y = Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1)) +
    geom_point()
# Out:
# plot without title

# %%
#Scatter Plot Income_Category (H) dengan Naive Bayes (V)
ggplot(BankChurners, aes(x = Income_Category, y = Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1)) +
    geom_point()
# Out:
# plot without title

# %%
#Scatter Plot Credit_Limit (N) dengan Naive Bayes (V)
ggplot(BankChurners, aes(x = Credit_Limit, y = Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1)) +
    geom_point()
# Out:
# plot without title

# %%
#Scatter Plot Total_Trans_Amt (R) dengan Naive Bayes (V)
ggplot(BankChurners, aes(x = Total_Trans_Amt, y = Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1)) +
    geom_point()
# Out:
# plot without title

# %%
# Membuat R Scatter Plot dengan Lattice Library
library(lattice)
# Creating Scatter Plot
xyplot(Customer_Age ~ Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1, data = BankChurners)
# Out:
# plot without title

# %%
# Membuat R Scatter Plot dengan Lattice Library
library(lattice)
# Creating Scatter Plot
xyplot(Total_Trans_Amt ~ Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1, data = BankChurners)
# Out:
# plot without title

# %% [markdown]
# Coba Korelasi Matriks
